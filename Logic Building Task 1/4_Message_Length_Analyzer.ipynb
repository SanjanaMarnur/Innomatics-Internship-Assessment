# %%
messages = ["Hi", "Welcome to the platform", "OK"]

flagged_msgs = []
for msg in messages:
  print(f"Length of the message '{msg}': {len(msg)}")
  if len(msg) > 10:
    flagged_msgs.append(msg)

print()
print(f"Flagged Messages are:")
print(flagged_msgs)
# Out:
# Length of the message 'Hi': 2
# Length of the message 'Welcome to the platform': 23
# Length of the message 'OK': 2
#
# Flagged Messages are:
# ['Welcome to the platform']
